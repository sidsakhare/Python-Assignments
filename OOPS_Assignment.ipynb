# %% [markdown]
# <a href="https://colab.research.google.com/github/sidsakhare/Python-Assignments/blob/main/OOPS_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Therotical Questions

# %% [markdown]
# 1. What is Object-Oriented Programming (OOP)?
#
# - Object-Oriented Programming is a programming paradigm that organizes code into objects that represent real-world entities, combining data (attributes) and behavior (methods).

# %% [markdown]
# 2. What is a class in OOP?
#
# - A class is a blueprint or template used to create objects. It defines the attributes and methods that the objects will have.

# %% [markdown]
# 3. What is an object in OOP?
#
# - An object is an instance of a class. It represents a real-world entity and can access the class’s attributes and methods

# %% [markdown]
# 4. Difference between abstraction and encapsulation?
#
# - Abstraction hides implementation details and shows only essential features.
#
# - Encapsulation binds data and methods together and restricts direct access to data.

# %% [markdown]
# 5. What are dunder methods in Python?
#
# - Dunder (double underscore) methods are special methods in Python that start and end with __, such as __init__, __str__, used to define object behavior.

# %% [markdown]
# 6. Explain inheritance in OOP
#
# - Inheritance allows a class (child) to reuse properties and methods of another class (parent), promoting code reusability.

# %% [markdown]
# 7. What is polymorphism in OOP?
#
# - Polymorphism allows the same method name to perform different behaviors depending on the object calling it.

# %% [markdown]
# 8. How is encapsulation achieved in Python?
#
# - Encapsulation is achieved using:
#
#   Private variables (__variable)
#
#   Getter and setter methods

# %% [markdown]
# 9. What is a constructor in Python?
#
# - A constructor is a special method (__init__) that is automatically called when an object is created to initialize data.

# %% [markdown]
# 10. What are class methods and static methods?
#
# - Class method works with class variables and uses @classmethod
#
# - Static method does not access class or instance data and uses @staticmethod

# %% [markdown]
# 11. What is method overloading in Python?
#
# - Method overloading means having methods with the same name but different arguments. Python supports it using default or variable arguments.

# %% [markdown]
# 12. What is method overriding?
#
# - Method overriding occurs when a child class provides its own implementation of a parent class method.

# %% [markdown]
# 13. What is a property decorator?
#
# - The @property decorator allows a method to be accessed like an attribute, helping implement getter/setter logic.

# %% [markdown]
# 14. Why is polymorphism important in OOP?
#
# - Polymorphism improves flexibility, scalability, and code reusability by allowing the same interface for different behaviors.

# %% [markdown]
# 15. What is an abstract class in Python?
#
# - An abstract class is a class that cannot be instantiated and contains abstract methods that must be implemented by subclasses.

# %% [markdown]
# 16. Advantages of OOP
#
#   - Code reusability
#
#   - Better organization
#
#   - Easy maintenance
#
#   - Data security
#
#   - Scalability

# %% [markdown]
# 17. Difference between class variable and instance variable?
#
# - Class variable is shared among all objects.
#
# - Instance variable is unique to each object.

# %% [markdown]
# 18. What is multiple inheritance in Python?
#
# - Multiple inheritance allows a class to inherit from more than one parent class.

# %% [markdown]
# 19. Purpose of __str__ and __repr__
#
# - __str__ → user-friendly representation
#
# - __repr__ → developer/debug-friendly representation

# %% [markdown]
# 21. Significance of __del__ method
#
# - The __del__ method is a destructor that is called when an object is deleted or destroyed.

# %% [markdown]
# 22. Difference between @staticmethod and @classmethod
#
# - @staticmethod → no access to class or instance
#
# - @classmethod → can access and modify class variables

# %% [markdown]
# 23. How does polymorphism work with inheritance?
#
# - A child class can override parent methods, and the method called depends on the object type at runtime.

# %% [markdown]
# 24. What is method chaining?
#
# - Method chaining allows calling multiple methods in a single statement by returning self.

# %% [markdown]
# 25. Purpose of the __call__ method
#
# - The __call__ method allows an object to be called like a function.

# %%
#1. Create a parent class Animal with a method speak() that prints a generic message. Create a child class Dog
#that overrides the speak() method to print "Bark!".

class Animal:

  def speak():

    print("This is a Animal voice")

class Dog(Animal):

  def speak():

    print("Bark!")

# %%
puppy = Dog
puppy.speak()
# Out:
# Bark!

# %%
puppy = Animal
puppy.speak()
# Out:
# This is a Animal voice

# %%
#2. Write a program to create an abstract class Shape with a method area(). Derive classes Circle and Rectangle
    #from it and implement the area() method in both.
import abc
class Shape:

  @abc.abstractmethod

  def area(self):

    pass


class Circle(Shape):

  def __init__(self,r):
    self.r = r

  def area(self):

    return 2.34* self.r **2

class Rectangle(Shape):

  def __init__(self,L,W):

    self.L = L

    self.W = W

  def area(self):

    return self.L * self.W

# %%
circle1 = Circle(20)

circle1.area()
# Out:
# 936.0

# %%
rectangle1 = Rectangle(20,30)

rectangle1.area()
# Out:
# 600

# %%
#3. Implement a multi-level inheritance scenario where a class Vehicle has an attribute type. Derive a class Car
    #and further derive a class ElectricCar that adds a battery attribute.

class Vehicle:

  def __init__(self,types):

    self.types = types
  def info_vehicle(self):
    print(f"this is the carr of {self.types} this type")

class car(Vehicle):

  def __init__(self,colours,types):

    self.colours = colours

    super().__init__(types)



  def car_info(self,colours,types):
    print(f"this is the colour of car{self.colours} and this is the {self.types}")

class ElectricCar(car):

  def __init__(self,battery,types,colours):
     super().__init__(types,colours)

     self.battery = battery


  def Electriccar_info(self,battery,types,colours):
    print(f"this is the {self.types},{self.colours},{self.battery}")

# %%
car1 = ElectricCar("50kw","red","massrati")
car1.Electriccar_info("50kw", "bmw","red")
# Out:
# this is the massrati,red,50kw

# %%
#Demonstrate polymorphism by creating a base class Bird with a method fly(). Create two derived classes
 #Sparrow and Penguin that override the fly() method.
class bird:
  def fly(self):
    print("this is the bird flying")

class Penguin(bird):

  def fly(self):
    print("unable to fly")

class sparrow(bird):

  def fly(self):
    print("this is the bird sparrow that can fly")

# %%
animal= bird()
animal.fly()
# Out:
# this is the bird flying

# %%
animal = Penguin()
animal.fly()
# Out:
# unable to fly

# %%
animal = sparrow()
animal.fly()
# Out:
# this is the bird sparrow that can fly

# %%
#5. Write a program to demonstrate encapsulation by creating a class BankAccount with private attributes
#balance and methods to deposit, withdraw, an d check balance

class bankaccount:

  def __init__(self,balance):

    self._balance = balance

  def deposite(self,amount):

    self._balance =  amount + self._balance

    return self.balance

  def withdraw(self,amount):
    if amount < self._balance:

      self._balance = self._balance - amount

      return self._balance

    else:

      return ("u do not have sufficiant balance")

  def check_balance(self):
    return (f"this is your actual balance : {self._balance}")

# %%
rahul = bankaccount(1000)
rahul.withdraw(200)
# Out:
# 800

# %%
rahul.withdraw(110)
# Out:
# 690

# %%
rahul.check_balance()
# Out:
# 'this is your actual balance : 690'

# %%
#6. Demonstrate runtime polymorphism using a method play() in a base class Instrument. Derive classes Guitar
    #and Piano that implement their own version of play().

class Instrument:

  def __init__(self,tune):

      self.tune = tune

  def play(self):
      print(f"this is the instrument with tune: {self.tune}")

class Guitar(Instrument):

  def play(self):

    print(f"this is the intrument Gitar and tune is {self.tune}")

class Piano(Instrument):

   def play(self):

    print(f"this is the instrument Piano and tune is  {self.tune}")

# %%
instrument1 = [Instrument(tune = "padhani"), Guitar(tune = "padhanisa"),Piano(tune = "raga")]

for Instrument in instrument1:
  Instrument.play()
# Out:
# this is the instrument with tune: padhani
# this is the intrument Gitar and tune is padhanisa
# this is the instrument Piano and tune is  raga

# %%
Instrument2 = Guitar("pa dha ni sa")

Instrument2.play()
# Out:
# this is the intrument Gitar and tune is pa dha ni sa

# %%
#7. Create a class MathOperations with a class method add_numbers() to add two numbers and a static
 #method subtract_numbers() to subtract two numbers.

class MathOperations:

  @classmethod

  def add_numbers(cls,a,b):

    return (a+ b)

  @staticmethod

  def subtract_numbers(c,d):

    return c - d

# %%
math = MathOperations.add_numbers(3,2)
maths= MathOperations.subtract_numbers(4,5)

print(math)
print(maths)
# Out:
# 5
# -1

# %%
#8. Implement a class Person with a class method to count the total number of persons created.

class Person:

  total_persons = 0

  def __init__(self,name):

    self.name = name

    Person.total_persons += 1

  def get_person(self):

    return self.name

  @classmethod

  def Total_sum(cls):

    return cls.total_persons

# %%
name1 = Person("ajay")

print(f"the name if the person is : {name1.get_person()}")

print(f"the count to persons: {Person.Total_sum()}")

name2 = Person("vijay")

print(f"the name if the person is : {name2.get_person()}")

print(f"the count to persons: {Person.Total_sum()}")
# Out:
# the name if the person is : ajay
# the count to persons: 1
# the name if the person is : vijay
# the count to persons: 2

# %%
#9. Write a class Fraction with attributes numerator and denominator. Override the str method to display the
#fraction as "numerator/denominator".


class Fraction:

  def __init__(self,numerator,denominator):

    self.numerator = numerator

    self.denominator = denominator

  def __str__(self):

    return f"{self.numerator}/{self.denominator}"

# %%
fact1 = Fraction(3,5)

# %%
print(fact1.__str__())
# Out:
# 3/5

# %%
fact2 = Fraction(8,9)
print(fact2)
# Out:
# 8/9

# %%
#10. Demonstrate operator overloading by creating a class Vector and overriding the add method to add two
 #vectors.

class vector:

  def __init__(self,x,y):

    self.x = x

    self.y = y

  def vectors(self):

      print("this does nothing")

  def vectors(self,x= int()):

      print(f"this shows value of {x}")

  def vectors(self,x,y):

      print(f'This shows value of both {x} and {y}')

  def __add__(self,other):

    return vector(self.x + other.x , self.y + other.y)

  def result(self):

    print(f"this is the result x: {self.x}, {self.y}")

# %%
obj1 = vector(1,2)
obj2 = vector(6,7)

# %%
obj3 = obj1 + obj2

# %%
obj3.result()
# Out:
# this is the result x: 7, 9

# %%
#11. Create a class Person with attributes name and age. Add a method greet() that prints "Hello, my name is
#{name} and I am {age} years old."

class person:

  def __init__(self,name,age):

    self.name = name

    self.age = age

  def greet(self):

    print(f"My name is {self.name}, and age is {self.age}")

# %%
obj1 = person("vijay", 29)

obj1.greet()
# Out:
# My name is vijay, and age is 29

# %%
#12. Implement a class Student with attributes name and grades. Create a method average_grade() to compute
     #the average of the grades.

class student:

  def __init__(self,name,grades):

    self.name = name

    self.grades = grades

  def average_grade(self):


    if self.grades == 0:

      return 0

    else:



      AVG = sum(self.grades)/len(self.grades)

      return self.name, AVG

# %%
stu1 = student("vishal",[30,40,50,0,67])

stu1.average_grade()
# Out:
# ('vishal', 37.4)

# %%
#13. Create a class Rectangle with methods set_dimensions() to set the dimensions and area() to calculate the
      #area.

class Rectangle:
  def __init__(self, L=0, W=0):
    self.L = L
    self.W = W

  def set_dimensions(self, L , W):
    self.L = L
    self.W = W

  def area(self):
    return f"{self.L * self.W} sq.m"

# %%
rect1 = Rectangle()

rect1.set_dimensions(5,30)

rect1.area()
# Out:
# '150 sq.m'

# %%
#14. Create a class Employee with a method calculate_salary() that computes the salary based on hours worked
      #and hourly rate. Create a derived class Manager that adds a bonus to the salary.


class Employee:

  def __init__(self,hours_worked,hourly_rate):

    self.hours_worked = hours_worked

    self.hourly_rate = hourly_rate

  def Calculate_salary(self):

    return self.hours_worked*self.hourly_rate

class Manager(Employee):

  def __init__(self, bonus,hours_worked,hourly_rate):

    self.bonus = bonus

    super().__init__(hours_worked,hourly_rate)

  def Managers_salary(self):

    return  self.Calculate_salary() + self.bonus

# %%
Ajay =  Employee(40,800)

Ajay.Calculate_salary()
# Out:
# 32000

# %%
Vjay = Manager(500,40,1500)

Vjay.Managers_salary()
# Out:
# 60500

# %%
#15. Create a class Product with attributes name, price, and quantity. Implement a method total_price() that
      #calculates the total price of the product.

class product:

  def __init__(self,name,price,quantity):

    self.name = name

    self.price = price

    self.quantity = quantity

  def total_price(self):

    print(f"this is the name of the product {self.name} with quantity {self.quantity} price {self.price} and total price {self.price*self.quantity}")

# %%
toothpaste = product("coalgate", 50,2)

toothpaste.total_price()
# Out:
# this is the name of the product coalgate with quantity 2 price 50 and total price 100

# %%
#16. Create a class Animal with an abstract method sound(). Create two derived classes Cow and Sheep that
      #implement the sound() method.

import abc

class Animal:

  @abc.abstractmethod

  def sound(sound):

    pass

class Cow(Animal):

  def sound(self):

    print("this is the sound of a = MOO")

class Sheep(Animal):

  def sound(self):

    print("this is the sound of a sheep = Mhaa")

# %%
cow1 = Cow()

cow1.sound()
# Out:
# this is the sound of a = MOO

# %%
#17. Create a class Book with attributes title, author, and year_published. Add a method get_book_info() that
    # returns a formatted string with the book's details.


class Book:

  def __init__(self,title,author,year_published):

    self.title = title

    self.author = author

    self.year_published = year_published


  def get_book_info(self):

    return (f"Books details are  Title =  {self.title}, Author name = {self.author}, Year published = {self.year_published}")

# %%
Book1 = Book("The mask", "vijay", 1992)

Book1.get_book_info()
# Out:
# 'Books details are  Title =  The mask, Author name = vijay, Year published = 1992'

# %%
#18. Create a class House with attributes address and price. Create a derived class Mansion that adds an
    #attribute number_of_rooms.

class House:

  def __init__(self,address,price):

    self.address = address

    self.price = price

class Mansion(House):

  def __init__(self,number_of_rooms,address,price):

    self.number_of_rooms = number_of_rooms

    super().__init__(address,price)

  def House_info(self):

    print(f"the info of the house is address=  {self.address}, price = {self.price}, and number of rooms = {self.number_of_rooms}")

# %%
House1 = Mansion(5,"house no. 30/1", 5000000)

House1.House_info()
# Out:
# the info of the house is address=  house no. 30/1, price = 5000000, and number of rooms = 5
