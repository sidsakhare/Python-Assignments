# %% [markdown]
# #1. What is NumPy, and why is it widely used in Python?
#   NumPy (Numerical Python) is a library used for numerical computing in Python. It provides support for large, multi-dimensional arrays and matrices along with mathematical functions to operate on them. It is widely used because it is fast, memory-efficient, and forms the foundation for many data science and machine learning libraries.

# %% [markdown]
# ##2. How does broadcasting work in NumPy?
#   Broadcasting allows NumPy to perform operations on arrays of different shapes by automatically expanding the smaller array to match the shape of the larger one without copying data. This enables efficient element-wise operations.

# %% [markdown]
# ##3.What is a Pandas DataFrame?
#   A Pandas DataFrame is a two-dimensional, tabular data structure with labeled rows and columns. It is used for data manipulation and analysis, similar to a spreadsheet or SQL table.

# %% [markdown]
# ##4. Explain the use of the groupby() method in Pandas.
#   The groupby() method is used to split data into groups based on one or more columns, apply aggregation functions (like sum, mean, count), and combine the results.

# %% [markdown]
# ##5. Why is Seaborn preferred for statistical visualizations?
#   Seaborn provides built-in statistical plots, attractive default styles, and integrates well with Pandas DataFrames. It simplifies complex visualizations with fewer lines of code compared to Matplotlib.

# %% [markdown]
# ##6. What are the differences between NumPy arrays and Python lists?
#   NumPy arrays are faster and more memory-efficient.
#
#   Arrays support element-wise operations.
#
#   Lists can store mixed data types, while NumPy arrays store homogeneous data.
#
#   NumPy supports multi-dimensional arrays easily.

# %% [markdown]
# ##7. What is a heatmap, and when should it be used?
#   A heatmap is a graphical representation of data where values are represented by colors. It is commonly used to visualize correlation matrices or intensity of values across categories.

# %% [markdown]
# ##8. What does the term “vectorized operation” mean in NumPy?
#   Vectorized operations perform computations on entire arrays at once without using explicit Python loops, making the operations faster and more efficient.

# %% [markdown]
# ##9. How does Matplotlib differ from Plotly?
#   Matplotlib is a static plotting library mainly used for basic visualizations. Plotly provides interactive and dynamic visualizations with zooming, hovering, and web integration capabilities.

# %% [markdown]
# ##10. What is the significance of hierarchical indexing in Pandas?
#   Hierarchical indexing (MultiIndex) allows multiple levels of indexing on rows or columns. It helps organize complex datasets and perform advanced data analysis.

# %% [markdown]
# ##11. What is the role of Seaborn’s pairplot() function?
# pairplot() creates pairwise scatter plots between numerical variables and shows distributions on the diagonal. It is useful for exploratory data analysis.

# %% [markdown]
# ##12. What is the purpose of the describe() function in Pandas?
# The describe() function generates summary statistics such as count, mean, standard deviation, min, max, and quartiles for numerical columns.

# %% [markdown]
# ##13. Why is handling missing data important in Pandas?
# Missing data can affect analysis accuracy and model performance. Handling missing values ensures clean, reliable datasets for analysis.

# %% [markdown]
# ##14. What are the benefits of using Plotly for data visualization?
# Plotly provides interactive charts, web compatibility, 3D plots, dashboards, and better user engagement compared to static plots.

# %% [markdown]
# ##15. How does NumPy handle multidimensional arrays?
# NumPy uses the ndarray object to represent multi-dimensional arrays. It supports indexing, slicing, reshaping, and mathematical operations across dimensions.

# %% [markdown]
# ##16. What is the role of Bokeh in data visualization?
# Bokeh is a Python library for creating interactive visualizations for web browsers. It is commonly used for dashboards and real-time data applications.

# %% [markdown]
# ##17. Explain the difference between apply() and map() in Pandas.
# map() is used on Series for element-wise transformations.
#
# apply() can be used on both Series and DataFrames and allows applying custom functions across rows or columns.

# %% [markdown]
# ##18. What are some advanced features of NumPy?
# Broadcasting
#
# Vectorization
#
# Linear algebra functions
#
# Random number generation
#
# Fourier transforms
#
# Masking and advanced indexing

# %% [markdown]
# ##19. How does Pandas simplify time series analysis?
# Pandas provides datetime indexing, resampling, shifting, rolling window calculations, and time-based grouping, making time series analysis easier.

# %% [markdown]
# ##20. What is the role of a pivot table in Pandas?
# A pivot table summarizes data by reorganizing it based on specified rows and columns and applying aggregation functions.

# %% [markdown]
# ##21. Why is NumPy’s array slicing faster than Python’s list slicing?
# NumPy slicing returns a view (not a copy) of the original data and is implemented in optimized C code, making it faster and memory-efficient.

# %% [markdown]
# ##22. What are some common use cases for Seaborn?
# Correlation heatmaps
#
# Distribution plots
#
# Box plots
#
# Violin plots
#
# Pair plots
#
# Regression plots

# %%
##1.How do you create a 2D NumPy array and calculate the sum of each row?
import numpy as np


A = np.random.randint(1,5,size  = (3,3))
print("Array\n:",A)
print("Sum of each row: ",np.sum(A,axis= 1))
# Out:
# Array
# : [[4 3 3]
#  [2 4 2]
#  [4 2 4]]
# Sum of each row:  [10  8 10]

# %%
##2.Write a Pandas script to find the mean of a specific column in a DataFrame?
import pandas as pd

A = {'key1':[1,2,3],'key2':[3,4,5],'key3':[4,5,6]}
df =pd.DataFrame(A)
df
# Out:
#    key1  key2  key3
# 0     1     3     4
# 1     2     4     5
# 2     3     5     6

# %%
mean_val = df['key1'].mean()
print('Mean of  dataframe: ',mean_val)
# Out:
# Mean of  dataframe:  2.0

# %%
import numpy as np
import matplotlib.pyplot as plt

study_hours = np.random.randint(1, 10, size=20)
exam_marks = study_hours * 10 + np.random.randint(-10, 10, size=20)

plt.scatter(study_hours, exam_marks)
plt.xlabel("Study Hours")
plt.ylabel("Exam Marks")
plt.title("Study Hours vs Exam Marks")
plt.show()

# %%
##How do you calculate the correlation matrix using Seaborn and visualize it with a heatmap
import seaborn as sns

data = sns.load_dataset('iris')

# %%
data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
data.drop('species', axis=1,inplace = True)

# %%
corr1 = data.corr()

# %%
data1 =sns.heatmap(corr1,cmap= 'coolwarm', annot= True, cbar_kws={'label': 'Correlation'})

# %%
#Generate a bar plot using Plotly.
import plotly.express as px
import plotly.graph_objects as go

# %%
data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %%
fig = go.Figure()
fig.add_trace(go.Bar(x = data['sepal_length'], y = data['sepal_width'] , name = "Legend name"))
fig.update_layout(title = "Length x Width of sepal", xaxis_title = "X axis", yaxis_title = "Y axis")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#6.Create a DataFrame and add a new column based on an existing column

data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eva'],
    'Age': [24, 27, 22, 32, 29],
    'City': ['New York', 'Los Angeles', 'Chicago', 'Houston', 'Miami'],
    'Score': [85.5, 92.1, 78.9, 88.0, 95.3]
}

# %%
df = pd.DataFrame(data)
df['Name(Age)'] = df['Name'] +"-"+ df['Age'].astype(str)
df
# Out:
#       Name  Age         City  Score   Name(Age)
# 0    Alice   24     New York   85.5    Alice-24
# 1      Bob   27  Los Angeles   92.1      Bob-27
# 2  Charlie   22      Chicago   78.9  Charlie-22
# 3    David   32      Houston   88.0    David-32
# 4      Eva   29        Miami   95.3      Eva-29

# %%
#7.Write a program to perform element-wise multiplication of two NumPy arrays
arr1 = np.array([1,2,3,4,5])
arr2 = np.array([6,7,8,9,10])
arr1 * arr2
# Out:
# array([ 6, 14, 24, 36, 50])

# %%
#8.Create a line plot with multiple lines using Matplotlib

df =pd.DataFrame(data)
plt.plot(df['Age'], df["Score"], color = 'b', marker= 'o', linestyle = '-' , linewidth = 1, markersize = 3, label = ' Age vs Score')
plt.xlabel('Age')
plt.ylabel('Score')
plt.legend()
plt.show()

# %%
#8.Generate a Pandas DataFrame and filter rows where a column value is greater than a threshold

# %%
tips =sns.load_dataset('tips')
tips = tips[(tips['total_bill'] > 20) & (tips['tip'] > 2)]
tips
# Out:
#      total_bill   tip     sex smoker  day    time  size
# 2         21.01  3.50    Male     No  Sun  Dinner     3
# 3         23.68  3.31    Male     No  Sun  Dinner     2
# 4         24.59  3.61  Female     No  Sun  Dinner     4
# 5         25.29  4.71    Male     No  Sun  Dinner     4
# 7         26.88  3.12    Male     No  Sun  Dinner     4
# ..          ...   ...     ...    ...  ...     ...   ...
# 219       30.14  3.09  Female    Yes  Sat  Dinner     4
# 227       20.45  3.00    Male     No  Sat  Dinner     4
# 229       22.12  2.88  Female    Yes  Sat  Dinner     2
# 238       35.83  4.67  Female     No  Sat  Dinner     3
# 239       29.03  5.92    Male     No  Sat  Dinner     3
#
# [89 rows x 7 columns]

# %%
#9.Create a histogram using Seaborn to visualize a distribution
tips
x = tips['total_bill'].astype(int)
sns.histplot(x , bins = 20, kde = True)
plt.title("Distribution of Total Bill")
plt.xlabel("Total Bill")
plt.ylabel("Frequency")

plt.show()

# %%
#10.Perform matrix multiplication using NumPy Array
mat1 = np.random.randint(1,100,(3,4))
mat2 = np.random.randint(1,100,(4,3))
mat1 @ mat2
# Out:
# array([[ 8421, 11523, 14865],
#        [11889, 11361, 15553],
#        [ 8008, 11314, 11295]])

# %%
#Use Pandas to load a CSV file and display its first 5 rows
df = pd.read_csv(r'/content/sample_data/california_housing_test.csv')
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
# 2    -117.81     33.78                27.0       3589.0           507.0
# 3    -118.36     33.82                28.0         67.0            15.0
# 4    -119.67     36.33                19.0       1241.0           244.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0
# 1       809.0       277.0         3.5990            176500.0
# 2      1484.0       495.0         5.7934            270500.0
# 3        49.0        11.0         6.1359            330000.0
# 4       850.0       237.0         2.9375             81700.0

# %%
#Create a 3D scatter plot using Plotly.
fig = px.scatter_3d(x= 'population' , y = "median_income", z = 'median_house_value', data_frame=df)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# !git config --global user.name "sidsakhare"
# !git config --global user.email "siddheshwarsakhare2002@gmail.com"

# %%
# %cd /content
# !git clone https://github.com/sidsakhare/Python-Assignments.git
# Out:
# /content
# fatal: destination path 'Python-Assignments' already exists and is not an empty directory.

# %%
# %cd Python-Assignments
# Out:
# /content/Python-Assignments

# %%
# !ls
# Out:
# Data_Structure_Assignment.ipynb
# Data_Toolkit_.ipynb
# Files,_exceptional_handling,_logging_and_memory_management.ipynb
# Functions_Assignment.ipynb
# OOPS_Assignment.ipynb
# Python_Assignment1.ipynb
# Python-Assignments
# README.md

# %%
# !cp "/content/drive/MyDrive/Colab Notebooks/Data Toolkit .ipynb" "Data_Toolkit_.ipynb"

# %%
# !git pull origin main
# !git add .
# !git commit -m "Updated assignment"
# !git push origin main
# Out:
# From https://github.com/sidsakhare/Python-Assignments
#  * branch            main       -> FETCH_HEAD
# Already up to date.
# ...
# hint: You've added another git repository inside your current repository.
# hint: Clones of the outer repository will not contain the contents of
# hint: the embedded repository and will not know how to obtain it.
# hint: If you meant to add a submodule, use:
# hint:
# hint: 	git submodule add <url> Python-Assignments
# hint:
# hint: If you added this path by mistake, you can remove it from the
# hint: index with:
# hint:
# hint: 	git rm --cached Python-Assignments
# hint:
# hint: See "git help submodule" for more information.
# [main 3800772] Updated assignment
#  2 files changed, 2 insertions(+), 1 deletion(-)
#  create mode 160000 Python-Assignments
# Enumerating objects: 5, done.
# Counting objects: 100% (5/5), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (3/3), done.
# ...
